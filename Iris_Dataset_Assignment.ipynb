# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanchauhan012/Iris-Dataset-Analysis/blob/main/Iris_Dataset_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None, names = ['sl','sw','pl','pw','species'])

# %%
df = iris.copy()

# %%
df.head(5)
# Out:
#     sl   sw   pl   pw      species
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.sl
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
df['sl'],df['sw']
# Out:
# (0      5.1
#  1      4.9
#  2      4.7
#  3      4.6
#  4      5.0
#        ...
#  145    6.7
#  146    6.3
#  147    6.5
#  148    6.2
#  149    5.9
#  Name: sl, Length: 150, dtype: float64,
#  0      3.5
#  1      3.0
#  2      3.2
#  3      3.1
#  4      3.6
#        ...
#  145    3.0
#  146    2.5
#  147    3.0
#  148    3.4
#  149    3.0
#  Name: sw, Length: 150, dtype: float64)

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  species
# 0    False  False  False  False    False
# 1    False  False  False  False    False
# 2    False  False  False  False    False
# 3    False  False  False  False    False
# 4    False  False  False  False    False
# ..     ...    ...    ...    ...      ...
# 145  False  False  False  False    False
# 146  False  False  False  False    False
# 147  False  False  False  False    False
# 148  False  False  False  False    False
# 149  False  False  False  False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl         0
# sw         0
# pl         0
# pw         0
# species    0
# dtype: int64

# %%
df.iloc[1:4, 1:4]
# Out:
#     sw   pl   pw
# 1  3.0  1.4  0.2
# 2  3.2  1.3  0.2
# 3  3.1  1.5  0.2

# %%
df['sl'].sum()
# Out:
# 876.5

# %%
df[(df.sl > 7) & (df.pl > 6.5)]
# Out:
#       sl   sw   pl   pw         species
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 122  7.7  2.8  6.7  2.0  Iris-virginica

# %%
df.groupby('species').describe()
# Out:
#                    sl                                                sw  \
#                 count   mean       std  min    25%  50%  75%  max count
# species
# Iris-setosa      50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8  50.0
# Iris-versicolor  50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0  50.0
# Iris-virginica   50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9  50.0
#
#                         ...     pl         pw                                  \
#                   mean  ...    75%  max count   mean       std  min  25%  50%
# species                 ...
# Iris-setosa      3.418  ...  1.575  1.9  50.0  0.244  0.107210  0.1  0.2  0.2
# Iris-versicolor  2.770  ...  4.600  5.1  50.0  1.326  0.197753  1.0  1.2  1.3
# Iris-virginica   2.974  ...  5.875  6.9  50.0  2.026  0.274650  1.4  1.8  2.0
#
#
#                  75%  max
# species
# Iris-setosa      0.3  0.6
# Iris-versicolor  1.5  1.8
# Iris-virginica   2.3  2.5
#
# [3 rows x 32 columns]

# %%
df.groupby('species').mean()
# Out:
#                     sl     sw     pl     pw
# species
# Iris-setosa      5.006  3.418  1.464  0.244
# Iris-versicolor  5.936  2.770  4.260  1.326
# Iris-virginica   6.588  2.974  5.552  2.026

# %%
df.groupby('species').mean()['pw']
# Out:
# species
# Iris-setosa        0.244
# Iris-versicolor    1.326
# Iris-virginica     2.026
# Name: pw, dtype: float64

# %%
df = df.drop(0)

# %%
df.head(5)
# Out:
#     sl   sw   pl   pw      species
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df = iris

# %% [markdown]
# df= df.drop(0) and df.drop(0, inplace= True) are equal.
#
# ```

# %%
df.drop(0, inplace= True)

# %%
df
# Out:
#       sl   sw   pl   pw         species
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.drop('sl', axis=1)
# Out:
#       sw   pl   pw         species
# 1    3.0  1.4  0.2     Iris-setosa
# 2    3.2  1.3  0.2     Iris-setosa
# 3    3.1  1.5  0.2     Iris-setosa
# 4    3.6  1.4  0.2     Iris-setosa
# 5    3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...             ...
# 145  3.0  5.2  2.3  Iris-virginica
# 146  2.5  5.0  1.9  Iris-virginica
# 147  3.0  5.2  2.0  Iris-virginica
# 148  3.4  5.4  2.3  Iris-virginica
# 149  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 4 columns]

# %%
df['sum']= df['sl'] + df['sw']
df
# Out:
#       sl   sw   pl   pw         species  sum
# 1    4.9  3.0  1.4  0.2     Iris-setosa  7.9
# 2    4.7  3.2  1.3  0.2     Iris-setosa  7.9
# 3    4.6  3.1  1.5  0.2     Iris-setosa  7.7
# 4    5.0  3.6  1.4  0.2     Iris-setosa  8.6
# 5    5.4  3.9  1.7  0.4     Iris-setosa  9.3
# ..   ...  ...  ...  ...             ...  ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica  9.7
# 146  6.3  2.5  5.0  1.9  Iris-virginica  8.8
# 147  6.5  3.0  5.2  2.0  Iris-virginica  9.5
# 148  6.2  3.4  5.4  2.3  Iris-virginica  9.6
# 149  5.9  3.0  5.1  1.8  Iris-virginica  8.9
#
# [149 rows x 6 columns]

# %%
df1 = df.groupby('species').count()['sl']
print(df1)
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: sl, dtype: int64

# %%
print(df1.values[0],df1.values[1],df1.values[2])
# Out:
# 50 50 50

# %%
df[(df.pl > 1.5) & (df.species == 'Iris-virginica')]
# Out:
#       sl   sw   pl   pw         species
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %%
count = df['species'].value_counts()
count
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.groupby('species').agg(['mean','min','max']).round(2)
# Out:
#                    sl              sw              pl              pw       \
#                  mean  min  max  mean  min  max  mean  min  max  mean  min
# species
# Iris-setosa      5.01  4.3  5.8  3.42  2.3  4.4  1.46  1.0  1.9  0.24  0.1
# Iris-versicolor  5.94  4.9  7.0  2.77  2.0  3.4  4.26  3.0  5.1  1.33  1.0
# Iris-virginica   6.59  4.9  7.9  2.97  2.2  3.8  5.55  4.5  6.9  2.03  1.4
#
#
#                  max
# species
# Iris-setosa      0.6
# Iris-versicolor  1.8
# Iris-virginica   2.5
